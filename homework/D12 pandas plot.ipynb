# %%
import pandas as pd
import numpy as np

# %%
#1.畫出箱型圖，並判斷哪個欄位的中位數在300~400之間?
df = pd.read_csv('boston_0201.csv')
df.boxplot()
df2 = pd.DataFrame(df.median(), columns = ['median'])
df2[(df2['median'] > 300) & (df2['median'] < 400)]
# Out:
#      median
# TAX  330.00
# B    391.43

# %%
#2. 畫出散佈圖 x='NOX', y='DIS' ，並說明這兩欄位有什麼關係?
df.plot.scatter(x = 'NOX', y = 'DIS')
# Out:
# <AxesSubplot:xlabel='NOX', ylabel='DIS'>
